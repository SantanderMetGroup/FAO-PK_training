# %%
rm(list = ls())

## params ##
dirbase = "/home/jovyan"
dirdata.era5 = "https://thredds.climate.ifca.es/thredds/dodsC/fao/trainings/pakistan-202608/data/era5"

## libraries ##
library(loadeR)
#library(transformeR)
library(visualizeR)
library(sf)

## auxiliary functions ##
source(sprintf("%s/notebooks/auxiliary_functions.R", dirbase))

# %%
## loading tmax from ERA5 (for January 2000) ##
era5 = loadGridData(sprintf("%s/tmax.nc", dirdata.era5),
                    var = "tmax", 
                    lonLim = c(60, 80), latLim = c(22, 38),
                    years = 2000, season = 1)
spatialPlot(climatology(era5), backdrop.theme = "countries")
# Out:
# [2026-07-21 18:04:28.005358] Opening dataset...
#
# [2026-07-21 18:04:30.655573] The dataset was successfuly opened
#
# [2026-07-21 18:04:30.664848] Defining geo-location parameters
#
# [2026-07-21 18:04:30.864424] Defining time selection parameters
#
# [2026-07-21 18:04:31.074394] Retrieving data subset ...
#
# [2026-07-21 18:04:32.551344] Done
#
# [2026-07-21 18:04:32.5562] - Computing climatology...
#
# [2026-07-21 18:04:32.651778] - Done.
# plot without title

# %%
## extracting data within the boundaries of the shapefile ##
era5.cropped = maskGrid(era5, sprintf("%s/pk_shp/pk.shp", dirbase)
spatialPlot(climatology(era5.cropped), backdrop.theme = "countries")
# Out:
# Warning message in CPL_read_ogr(dsn, layer, query, as.character(options), quiet, :
# “GDAL Error 4: Unable to open /home/jovyan/data/pk_shp/pk.shx or /home/jovyan/data/pk_shp/pk.SHX. Set SHAPE_RESTORE_SHX config option to YES to restore or create it.”
# Error: Cannot open "/home/jovyan/data/pk_shp/pk.shp"; The source could be corrupt or not supported. See `st_drivers()` for a list of supported formats.
# Traceback:
#
# 1. st_read(shape, quiet = TRUE)
# 2. st_read.character(shape, quiet = TRUE)
# 3. CPL_read_ogr(dsn, layer, query, as.character(options), quiet,
#  .     type, fid_column_name, drivers, wkt_filter, promote_to_multi,
#  .     int64_as_string, dsn_exists, dsn_isdb, getOption("width"))
# 4. stop(structure(list(message = "Cannot open \"/home/jovyan/data/pk_shp/pk.shp\"; The source could be corrupt or not supported. See `st_drivers()` for a list of supported formats.",
#  .     call = NULL, cppstack = NULL), class = c("Rcpp::exception",
#  . "C++Error", "error", "condition")))
